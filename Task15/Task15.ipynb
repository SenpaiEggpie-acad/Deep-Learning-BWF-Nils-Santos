# %%
import pandas as pd
import numpy as np

# %%
movie_df = pd.read_csv('trending.csv')
movie_df = movie_df.drop(columns='Unnamed: 0')

# %%
movie_df
# Out:
#            id            original_title original_language release_date  \
# 0      638974          Murder Mystery 2           English   2023-03-26
# 1      677179                 Creed III           English   2023-03-01
# 2      726759                    Tetris           English   2023-03-15
# 3       76600  Avatar: The Way of Water           English   2022-12-14
# 4      849869                       길복순            Korean   2023-02-17
# ...       ...                       ...               ...          ...
# 16075  117465                       NaN          Japanese          NaN
# 16076  933419                 Champions           English   2023-03-09
# 16077  208891                       NaN          Japanese          NaN
# 16078  878375    On a Wing and a Prayer           English   2023-04-06
# 16079   82856                       NaN           English          NaN
#
#        popularity  vote_average  vote_count media_type  adult
# ...

# %%
#Dropping rows with Nan
movie_df = movie_df.dropna()

# %%
movie_df = movie_df.reset_index().drop(columns='index')
movie_df
# Out:
#             id                     original_title original_language  \
# 0       638974                   Murder Mystery 2           English
# 1       677179                          Creed III           English
# 2       726759                             Tetris           English
# 3        76600           Avatar: The Way of Water           English
# 4       849869                                길복순            Korean
# ...        ...                                ...               ...
# 12055  1049638                           Rye Lane           English
# 12056   739405  Operation Fortune: Ruse de Guerre           English
# 12057   921355                           Assassin           English
# 12058   933419                          Champions           English
# 12059   878375             On a Wing and a Prayer           English
#
#       release_date  popularity  vote_average  vote_count media_type  adult
# 0       2023-03-26     235.901         6.800         187      movie  False
# ...
